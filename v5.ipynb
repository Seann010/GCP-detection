# %%
from ultralytics import YOLO

model = YOLO("yolov5xu.pt")
model.train(
    data="datatiled.yaml",
    epochs=20,
    imgsz=512,
    lr0=0.001,
    optimizer='AdamW',
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#       3 model = YOLO("yolov5xu.pt")
#       4 model.train(
#       5     data="datatiled.yaml",
#       6     epochs=20,
#    (...)      9     optimizer='AdamW',
#      10 )
#
# ModuleNotFoundError: No module named 'ultralytics'
